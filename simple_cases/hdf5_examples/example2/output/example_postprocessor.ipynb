# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
f = h5py.File('field.h5')

# %%
# list keys in the h5 file
f.keys()
# Out:
# <KeysViewHDF5 ['breakwater', 'dep', 'eta', 'mask']>

# %%
# list attriburtes(parameters) in the h5 file
print(f.attrs.keys())
print(f.attrs['out_count'])
# Out:
# <KeysViewHDF5 ['dx', 'dy', 'nx', 'ny', 'out_count', 'out_interval']>
# [19]

# %%
# list keys in the h5 file at the second level
print(f['breakwater'].keys())
print(f['dep'].keys())
print(f['eta'].keys())
print(f['mask'].keys())
# Out:
# <KeysViewHDF5 ['cd_breakwater.out']>
# <KeysViewHDF5 ['dep.out']>
# <KeysViewHDF5 ['eta_00000', 'eta_00001', 'eta_00002', 'eta_00003', 'eta_00004', 'eta_00005', 'eta_00006', 'eta_00007', 'eta_00008', 'eta_00009', 'eta_00010', 'eta_00011', 'eta_00012', 'eta_00013', 'eta_00014', 'eta_00015', 'eta_00016', 'eta_00017', 'eta_00018', 'eta_00019']>
# <KeysViewHDF5 ['mask_00000', 'mask_00001', 'mask_00002', 'mask_00003', 'mask_00004', 'mask_00005', 'mask_00006', 'mask_00007', 'mask_00008', 'mask_00009', 'mask_00010', 'mask_00011', 'mask_00012', 'mask_00013', 'mask_00014', 'mask_00015', 'mask_00016', 'mask_00017', 'mask_00018', 'mask_00019']>

# %%
data = np.array(f['eta']['eta_00019'])
print(np.shape(data))
plt.plot(data[1,:])
# Out:
# (3, 1024)
