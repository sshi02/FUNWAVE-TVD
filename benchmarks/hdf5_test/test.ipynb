# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
f = h5py.File('output/field.h5')

# %%
# list keys in the h5 file
f.keys()
# Out:
# <KeysViewHDF5 ['breakwater', 'dep', 'eta', 'mask']>

# %%
# list attriburtes(parameters) in the h5 file
print(f.attrs.keys())
print(f.attrs['out_count'])
# Out:
# <KeysViewHDF5 ['dx', 'dy', 'nx', 'ny', 'out_count', 'out_interval']>
# [19]

# %%
# list keys in the h5 file at the second level
print(f['breakwater'].keys())
print(f['dep'].keys())
print(f['eta'].keys())
print(f['mask'].keys())
# Out:
# <KeysViewHDF5 ['breakwater']>
# <KeysViewHDF5 ['depth']>
# <KeysViewHDF5 ['00000', '00001', '00002', '00003', '00004', '00005', '00006', '00007', '00008', '00009', '00010', '00011', '00012', '00013', '00014', '00015', '00016', '00017', '00018', '00019']>
# <KeysViewHDF5 ['00000', '00001', '00002', '00003', '00004', '00005', '00006', '00007', '00008', '00009', '00010', '00011', '00012', '00013', '00014', '00015', '00016', '00017', '00018', '00019']>

# %%
data = np.array(f['eta']['00019'])
print(np.shape(data))
plt.plot(data[1,:])
# Out:
# (3, 1024)
